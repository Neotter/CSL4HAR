# %%
# !conda env list
# Out:
# # conda environments:
# #
# base                     C:\Users\tinkl\ProgramFiles\miniconda
# pt111                    C:\Users\tinkl\ProgramFiles\miniconda\envs\pt111
# pt112                 *  C:\Users\tinkl\ProgramFiles\miniconda\envs\pt112
# yolo6                    C:\Users\tinkl\ProgramFiles\miniconda\envs\yolo6

# %%
# !python main_pretrain.py -d uci -v 20_120 -a spanmasking
# !python main_embedding.py -d uci -v 20_120 -a spanmasking -p ./saved/pretrain/scsense/uci-embed_dim72-lr1e-03/model_epoch2396.pth
export CUDA_VISIBLE_DEVICES=2 && python main_embedding.py -d uci -v 20_120 -a spanmasking -p

# %%
# 测试spanmasking 0.4
# !export CUDA_VISIBLE_DEVICES=1 && python main_pretrain.py -d uci -v 20_120 -a spanmasking

# %%
# 测试delword 0.4
# !export CUDA_VISIBLE_DEVICES=0 && python main_pretrain.py -d uci -v 20_120 -a delwords
# Out:
# All logs will be saved to ./saved/pretrain/delwords@40.0/uci-embed_dim72-lr1e-04/log0.log
# ...
